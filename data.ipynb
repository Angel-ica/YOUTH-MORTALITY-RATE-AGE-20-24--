# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import geoplot as gp

# %%
#data=pd.read_csv('API_SH.DYN.2024_DS2_en_csv_v2_4543808.csv',sep=',')
data=pd.read_csv('hiv_2.csv')
new_data=pd.DataFrame(data)
print(new_data)
# Out:
#      Unnamed: 0                 Country Name       2015       2016       2017  \
# 0             0                        Aruba        NaN        NaN        NaN
# 1             1  Africa Eastern and Southern  14.589612  14.243878  13.965109
# 2             2                  Afghanistan  17.200000  17.600000  17.800000
# 3             3   Africa Western and Central  13.282576  12.998737  12.804327
# 4             4                       Angola  20.600000  20.000000  19.500000
# ..          ...                          ...        ...        ...        ...
# 261         261                       Kosovo        NaN        NaN        NaN
# 262         262                  Yemen, Rep.  11.900000  11.200000  12.000000
# 263         263                 South Africa  14.800000  14.200000  13.600000
# 264         264                       Zambia  15.300000  14.500000  13.800000
# 265         265                     Zimbabwe  16.400000  15.900000  15.500000
#
# ...

# %%
sns.barplot(y='2015',x='Country Name', data=new_data)
# Out:
# <AxesSubplot:xlabel='Country Name', ylabel='2015'>

# %%
compact_data ={
    'Country Name':['Somalia','Central African Republic','South Sudan','Mozambique','Palau','Democratic Rep.Congo','Chad','Venezuela','Guinea','Angola'],
    '2020':['24.3','23.6','22.1','21.1','21.0','19.7','19.3','19.2','18.3','18.1']
}
df=pd.DataFrame(data=compact_data)
csv=df.to_csv('compact_csv.csv')
new_csv_data=pd.read_csv('compact_csv.csv')
print(pd.DataFrame(new_csv_data))
# Out:
#    Unnamed: 0              Country Name  2020
# 0           0                   Somalia  24.3
# 1           1  Central African Republic  23.6
# 2           2               South Sudan  22.1
# 3           3                Mozambique  21.1
# 4           4                     Palau  21.0
# 5           5      Democratic Rep.Congo  19.7
# 6           6                      Chad  19.3
# 7           7                 Venezuela  19.2
# 8           8                    Guinea  18.3
# 9           9                    Angola  18.1
#                Country Name  2020
# 0                   Somalia  24.3
# 1  Central African Republic  23.6
# 2               South Sudan  22.1
# 3                Mozambique  21.1
# 4                     Palau  21.0
# 5      Democratic Rep.Congo  19.7
# 6                      Chad  19.3
# 7                 Venezuela  19.2
# 8                    Guinea  18.3
# 9                    Angola  18.1

# %%
sns.barplot(x='Country Name',y='2020', data=new_csv_data)
# Out:
# <AxesSubplot:xlabel='Country Name', ylabel='2020'>
